# %%
from graph_utils import Graph

# %%
g = Graph.from_organism("ORG-6001")
g.plot("Lactuca sativa (ORG-6001)")

# %%
from data_utils import get_popular_compounds
common_compoudns = list(get_popular_compounds()[:15].index)
common_compoudns
# Out:
# ['PROTON',
#  'WATER',
#  'OXYGEN-MOLECULE',
#  'ATP',
#  'NADPH',
#  'NADP',
#  'CO-A',
#  'CARBON-DIOXIDE',
#  'PPI',
#  'Pi',
#  'NAD',
#  'NADH',
#  'S-ADENOSYLMETHIONINE',
#  'ADENOSYL-HOMO-CYS',
#  'ADP']

# %%
g = Graph.from_organism("ORG-6001", include_reactions=False)
g = g.prune_compounds(common_compoudns)
g.plot("Lactuca sativa (ORG-6001)")

# %%
g = Graph.from_pathways(["PWY-5873"])
#g = g.prune_compounds(common_compoudns)
g.plot("ubiquinol-7 biosynthesis (PWY-5873)")

# %%
g = Graph.from_pathways(["PWY-5873"], include_reactions=False)
g = g.prune_compounds(common_compoudns)
g.plot("ubiquinol-7 biosynthesis (PWY-5873)")
